# %%
#Tratamento de dados: 

import pandas as pd     
pd.set_option('display.max_columns', None)   #Filtro das colunas  que queremos + Seu  arquivo salvo
#Caminho do seu arquivo Json
caminho_do_arquivo = r"C:\Users\manue\OneDrive\Desktop\Projeto_Anac-SGBDS\Anac\Arquivo Json\PecasAprovadas.json"
df = pd.read_json(caminho_do_arquivo, encoding='utf-8-sig')
df.head()
# Out:
#                              ORG_NOME  PAPP_COD           PAPP_NOME  \
# 0     AEROMOT AERONAVES E MOTORES S/A      4939   Pastilha de Freio
# 1  EMBRAER DIVISÃO EQUIPAMENTOS - EDE       579         Amortecedor
# 2  EMBRAER DIVISÃO EQUIPAMENTOS - EDE       581    Atuador de Porta
# 3  EMBRAER DIVISÃO EQUIPAMENTOS - EDE       583  Atuador Hidráulico
# 4  EMBRAER DIVISÃO EQUIPAMENTOS - EDE       584  Atuador Hidráulico
#
#               PAPP_PN                       PAPP_MODELO    APAA_CODI  \
# 0  AM-110121-32-13000  Para a aplicabilidade, ver CPAA.  2024P12-01A
# 1       2119-0001-001                                 -   2000P06-05
# 2       2106-2001-001                                 -   2000P06-02
# 3       2106-0500-001                                 -   2000P06-01
# 4       2108-0050-003                                 -   2000P06-03
#
#                  APAA_DATA APAA_STATUS PAPP_OTP     PAPP_REPOE  \
# 0  2025-08-27 00:00:00.000           V     None       Ver CPAA
# 1  2000-07-06 00:00:00.000           V     None  2119-0001-001
# 2  2000-07-06 00:00:00.000           V     None  2106-2001-001
# 3  2000-07-06 00:00:00.000           V     None  2106-0500-001
# 4  2000-07-06 00:00:00.000           V     None  2108-0050-003
#
#            PAPP_MAPROV                                 PAPP_MODELOAER  \
# 0  Subparte K, RBAC 21  Série EMB-121 [XINGU] e EMB-110 [BANDEIRANTE]
# 1                 None                                        EMB 145
# 2                 None                                        EMB 145
# 3                 None                                        EMB 145
# 4                 None                                        EMB 145
#
#   PAPP_TIPO ORG_NABREV_FAB_PROD PAPP_AUTORIDADE  ORG_CODI
# 0         R             AEROMOT            None       NaN
# 1         R         EMBRAER EDE            None       NaN
# 2         R         EMBRAER EDE            None       NaN
# 3         R         EMBRAER EDE            None       NaN
# 4         R         EMBRAER EDE            None       NaN

# %%
df.columns

# %%
colunas = ['ORG_NOME', 'PAPP_COD','PAPP_NOME' ,'PAPP_PN',
       'APAA_CODI', 'APAA_DATA', 'APAA_STATUS']
df = df[colunas]

# %%
df.head(10)

# %%
import   psycopg2

#Parametro de conexão:
dbname = 'seu banco'                  
user = 'seu usuario'
password = 'sua senha'            
host = 'localhost'
port = '5432'

#Cria uma conexão:
conexao= psycopg2.connect(
    dbname=dbname,
    user=user,
    password=password,
    host=host,
    port=port
)

#Cria uma cursor  para manipular os dados:
cursor = conexao.cursor()
#Delete base antes da Carga:
cursor.execute(" delete from Anac")

for indice,coluna_df in df.iterrows():
      cursor.execute( """  insert into  ANAC  (
				ORG_NOME,
				PAPP_COD,
				PAPP_NOME,
				PAPP_PN,
			    APAA_CODI,
				APAA_DATA,
				APAA_STATUS
		) VALUES (%s,%s,%s,%s,%s,%s,%s) 

		""", (
				coluna_df["ORG_NOME"],
				coluna_df["PAPP_COD"],
				coluna_df["PAPP_NOME"],
				coluna_df["PAPP_PN"],
				coluna_df["APAA_CODI"],
		    	coluna_df["APAA_DATA"],
				coluna_df["APAA_STATUS"]
		)
		
		 )
conexao.commit()
cursor.close()
conexao.close()
